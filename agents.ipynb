# %%
from pyneuphonic import Neuphonic, TTSConfig, Agent, AgentConfig
from pyneuphonic.player import AudioPlayer
from pyneuphonic import Neuphonic, WebsocketEvents, save_audio
from pyneuphonic.models import APIResponse, TTSResponse
import os
import asyncio

# %%
agent_id = client.agents.create(
    name='Agent 2',
    prompt='Eres un agente administrador de tareas.',
    greeting='Hola, ¿como puedo ayudarte hoy?'
).data['id']


agent = Agent(client, agent_id='e564ba7e-aa8d-46a2-96a8-8dffedade48f',mode = 'llm-tts', tts_model='neu_hq')

await agent.start()
