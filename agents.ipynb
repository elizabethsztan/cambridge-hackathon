# %%
from pyneuphonic import Neuphonic, TTSConfig, Agent, AgentConfig
from pyneuphonic.player import AudioPlayer
from pyneuphonic import Neuphonic, WebsocketEvents, save_audio
from pyneuphonic.models import APIResponse, TTSResponse
import os
import asyncio

# %%
api_key = "5410fa31cbb28a8ae871420afb4aa74a0148c654f91ac7ae9acd2f7f3dfa4582.2199bfcc-36d3-44d7-946d-0d76a99f2a51"

# %%
client = Neuphonic(api_key=api_key)
response = client.voices.list()  # get's all available voices
voices = response.data['voices']

# %%
response = client.agents.list()
response.data
# Out:
# {'agents': [{'id': 'f95d2f69-bda9-4a4f-aa7c-bdd789d07c66', 'name': 'Agent 1'},
#   {'id': 'e8a2bdd9-dc93-48a2-8692-23f0b1b1a6de', 'name': 'Agent 2'}]}

# %%
client.agents.delete(agent_id='749df5a5-f168-48f1-9f81-c8770a5b0588')
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 client.agents.delete(agent_id='749df5a5-f168-48f1-9f81-c8770a5b0588')
#
# File ~/Documents/DIS/Hackathon/neuphonic_venv/lib/python3.11/site-packages/pyneuphonic/_agents.py:152, in Agents.delete(self, agent_id)
#     128 """
#     129 Delete an agent.
#     130
#    (...)
#     144     If the request fails to delete.
#     145 """
#     146 response = httpx.delete(
#     147     f'{self.http_url}/agents/{agent_id}',
#     148     headers=self.headers,
#     149     timeout=self.timeout,
#     150 )
# --> 152 self.raise_for_status(response=response, message='Failed to delete agent.')
#     154 return APIResponse(**response.json())
#
# File ~/Documents/DIS/Hackathon/neuphonic_venv/lib/python3.11/site-packages/pyneuphonic/_endpoint.py:51, in Endpoint.raise_for_status(self, response, message)
# ...

# %%
new_agent_name = "Agent 2"
new_agent_prompt = ""
new_agent_greeting = "Hey! How can I help you today?"

new_agent_response = client.agents.create(
    name=new_agent_name,
    prompt=new_agent_prompt,
    greeting=new_agent_greeting,
).data['id']

# Instantiate and start the agent
new_agent = Agent(client, agent_id=new_agent_response, tts_model='neu_hq')
#
await new_agent.start()
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[6], line 14
#      12 new_agent = Agent(client, agent_id=new_agent_response, tts_model='neu_hq')
#      13 #
# ---> 14 await new_agent.start()
#
# File ~/Documents/DIS/Hackathon/neuphonic_venv/lib/python3.11/site-packages/pyneuphonic/agents.py:95, in Agent.start(self)
#      93 try:
#      94     while True:
# ---> 95         await asyncio.sleep(0.01)
#      96 except KeyboardInterrupt:
#      97     await self.ws.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/tasks.py:649, in sleep(delay, result)
#     645 h = loop.call_later(delay,
#     646                     futures._set_result_unless_cancelled,
#     647                     future, result)
#     648 try:
# --> 649     return await future
#     650 finally:
#     651     h.cancel()
#
# ...
